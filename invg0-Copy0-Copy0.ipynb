# %% [markdown]
# # Inverse G

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(0,5,21)

# %%
print(x)
# Out:
# [ 0.    0.25  0.5   0.75  1.    1.25  1.5   1.75  2.    2.25  2.5   2.75
#   3.    3.25  3.5   3.75  4.    4.25  4.5   4.75  5.  ]

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def func(x, t, k, m):
    return [x[2]/m, 
            x[3]/m, 
            -x[0]*x[1]*x[1]*k,
            -x[0]*x[0]*x[1]]

# %%
m=1
k=1
x0 = [0.0, 0.0, -1, -0.9]
t = np.arange(0, 100, 0.01)

# %%
x = odeint(func, x0, t, args=(k,m))

# %%
#fig = plt.figure()
#ax = fig.gca(projection='3d')
#ax.plot(x[:, 0], x[:, 1], x[:, 2])

# %%
h = np.column_stack([x[:,0],x[:,1]])
h.shape
# Out:
# (10000, 2)

# %%
U = x[:,0]*x[:,0]*x[:,1]*x[:,1]/2 
K =  (x[:,2]*x[:,2] + x[:,3]*x[:,3] )/(2*m)
H = U + K
plt.plot(t,np.column_stack([H,U,K]))
# Out:
# [<matplotlib.lines.Line2D at 0x5d17890>,
#  <matplotlib.lines.Line2D at 0x5d17a70>,
#  <matplotlib.lines.Line2D at 0x5d17c10>]

# %%
plt.plot(x[:,0],x[:,1])
